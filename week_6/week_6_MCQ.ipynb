# %% [markdown]
# # Week 6 mcq working ground

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# %matplotlib inline

mu = 0
variance = 2

sigma = np.sqrt(variance)
x = np.linspace(mu - 3*variance, mu + 3*variance, 100)
plt.plot(x, norm.pdf(x, mu, sigma))

# %%
mean = 50
std = 16
n = 64

std_sample_mean = np.sqrt(std)/np.sqrt(n)
print(std_sample_mean)
# Out:
# 0.5

# %%
sigma = 16
n = 64

std_error = sigma / np.sqrt(n)
print(std_error)
# Out:
# 2.0

# %%
import numpy as np
from scipy import stats

student_scores = np.array([55, 62, 67, 58, 63, 59, 61, 68, 60, 64])
mu = 60
x_bar = np.mean(student_scores)
s = np.std(student_scores, ddof=1)
n = len(student_scores)
alpha = 0.05

t_stat = (x_bar - mu) / (s / np.sqrt(n))
p_value = stats.t.cdf(t_stat, df=n-1) if t_stat < 0 else (1 - stats.t.cdf(t_stat, df=n-1))
p_value *= 2

print("T statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T statistic: 1.343501592923275
# P-value: 0.21200020507950157

# %%
import scipy.stats as stats
import numpy as np

mu = 370
sigma = 100
n = 40
x_bar = 400

std_error = sigma / np.sqrt(n)
z = (x_bar - mu) / std_error
prob = 1 - stats.norm.cdf(z)
print("Probability:", prob)
# Out:
# Probability: 0.028889785561798664

# %%
from scipy.stats import poisson

lambda_ = 8
k = 6

prob = poisson.pmf(k, lambda_)
print("Probability of exactly 6 customers:", prob)
# Out:
# Probability of exactly 6 customers: 0.12213821545677205

# %%
import numpy as np
from scipy.stats import norm

mu = 100
sigma = 15
n = 30
x_bar = 95

std_error = sigma / np.sqrt(n)
z = (x_bar - mu) / std_error
prob = norm.cdf(z)

print("Probability:", prob)
# Out:
# Probability: 0.033944577430914495
